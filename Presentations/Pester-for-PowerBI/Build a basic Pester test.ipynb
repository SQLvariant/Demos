# %% [markdown]
# <img src="https://app.powerbi.com/13.0.10537.111/images/PowerBI96x96.png?raw=true" width="10%">
# <img src="https://github.com/Microsoft/azuredatastudio/blob/master/samples/notebookSamples/Graphics/AzureDataStudioLogo.png?raw=true" width="10%">
#
# # Query a .PBIX file with DAX  PowerShell

# %% [markdown]
# Pester tests are comprised of 3 components
#
# - Describe
# - Context
# - It

# %%
2+35 | Should -Be 36
# Out:
# Expected 36, but got 37.
# At C:\Program Files\WindowsPowerShell\Modules\Pester\5.0.4\Pester.psm1:6902 char:13
# +             throw $errorRecord
# +             ~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : InvalidResult: (System.Collecti...,System.Object]:Dictionary`2) [], Exception
#     + FullyQualifiedErrorId : PesterAssertionFailed

# %%
Describe "Basic_Pester" {
    Context "Add numbers and test the results"{
        
        It "Should verify the count is correct by comparing against a static number" {
            2+34 | Should -Be 36
        }
        
        $a =2; $b = 34

        It "Should verify the first result (row) return matches static value" {
            $a + $b | Should -Be 36
        }        
    }

}

# %% [markdown]
# What are the comparison options?
#
# <span style="color: var(--ifm-heading-color); font-size: 3rem; font-weight: var(--ifm-heading-font-weight); font-family: &quot;Segoe UI&quot;, &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;">Performing Assertions with Should</span>
#
#
# `Should` is a command that provides assertion convenience methods for comparing objects and throwing test failures when test expectations fail. `Should` is used inside `It` blocks of a Pester test script.
#
# ## [](..\..\..\..\..\..)Negative Assertions[#](https://pester.dev/docs/usage/assertions#negative-assertions)
#
# When reviewing the operators listed below, keep in mind that all of them can be negated by putting the word "Not" between "Should" and the operator. For example:
#
# <span class="token boolean" style="box-sizing: border-box; color: rgb(54, 172, 170);">$true</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token boolean" style="box-sizing: border-box; color: rgb(54, 172, 170);">$true</span>
#
# <span class="token boolean" style="box-sizing: border-box; color: rgb(54, 172, 170);">$true</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Not</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token boolean" style="box-sizing: border-box; color: rgb(54, 172, 170);">$false</span>
#
# Copy
#
# ## [](..\..\..\..\..\..)Should Operators[#](https://pester.dev/docs/usage/assertions#should-operators)
#
# ### [](..\..\..\..\..\..)Be[#](https://pester.dev/docs/usage/assertions#be)
#
# Compares one object with another for equality and throws if the two objects are not the same. This comparison is not case sensitive.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span>\=<span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Actual value"</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"actual value"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"not actual value"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# Also compares an entire array for equality and throws if the array is not the same.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$array</span> = @<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 2<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 3<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 4<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I am a string'</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">New-Object</span> psobject <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Property @<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span> IAm = <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'An Object'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$array</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$array</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$string</span> = <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I am a string'</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$array</span> = @<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 2<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 3<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 4<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$string</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$arrayWithCaps</span> = @<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 2<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 3<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> 4<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$string</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>ToUpper<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$array</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$arrayWithCaps</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# Copy
#
# Comparisons will fail if the arrays have the same values, but not the same order.
#
# \[int32\[\]\]<span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$array</span> = <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>10<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$arrayoutoforder</span> = <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>10<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>2<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>3<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>4<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>5<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>6<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>7<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>8<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>9<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$array</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$arrayOutOfOrder</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)BeExactly[#](https://pester.dev/docs/usage/assertions#beexactly)
#
# Compares one object with another for equality and throws if the two objects are not the same. This comparison is case sensitive.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span>\=<span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Actual value"</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeExactly <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Actual value"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeExactly <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"actual value"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)BeGreaterThan[#](https://pester.dev/docs/usage/assertions#begreaterthan)
#
# Asserts that a number is greater than an expected value. Uses PowerShell's -gt operator to compare the two values.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$Error</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>Count <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeGreaterThan 0
#
# \[version\]<span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'2.3.4.5'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeGreaterThan <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>\[version\]<span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'1.0.0.1'</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Date</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>AddMinutes<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>5<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeGreaterThan <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Date</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)BeGreaterOrEqual[#](https://pester.dev/docs/usage/assertions#begreaterorequal)
#
# Asserts that a number (or other comparable value) is greater than or equal to an expected value. Uses PowerShell's -ge operator to compare the two values.
#
# 2 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeGreaterOrEqual 0
#
# 2 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeGreaterOrEqual 2
#
# Copy
#
# ### [](..\..\..\..\..\..)BeIn[#](https://pester.dev/docs/usage/assertions#bein)
#
# Asserts that the actual value is contained by the array/collection
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'b'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeIn @<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'a'</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span><span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'b'</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span><span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'c'</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# 27 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeIn <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>100<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)BeLessThan[#](https://pester.dev/docs/usage/assertions#belessthan)
#
# Asserts that a number is less than an expected value. Uses PowerShell's -lt operator to compare the two values.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$Error</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>Count <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeLessThan 1
#
# Copy
#
# ### [](..\..\..\..\..\..)BeLessOrEqual[#](https://pester.dev/docs/usage/assertions#belessorequal)
#
# Asserts that a number (or other comparable value) is lower than, or equal to an expected value. Uses PowerShell's -le operator to compare the two values.
#
# 1 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeLessOrEqual 10
#
# 10 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeLessOrEqual 10
#
# Copy
#
# ### [](..\..\..\..\..\..)BeLike[#](https://pester.dev/docs/usage/assertions#belike)
#
# Asserts that the actual value matches a wildcard pattern using PowerShell's -like operator. This comparison is not case-sensitive.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span>\=<span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Actual value"</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeLike <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"actual *"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeLike <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"not actual *"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)BeLikeExactly[#](https://pester.dev/docs/usage/assertions#belikeexactly)
#
# Asserts that the actual value matches a wildcard pattern using PowerShell's -clike operator. This comparison is case-sensitive.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span>\=<span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Actual value"</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeLikeExactly <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Actual *"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeLikeExactly <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"actual *"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)BeOfType[#](https://pester.dev/docs/usage/assertions#beoftype)
#
# Asserts that the actual value should be an object of a specified type (or a subclass of the specified type) using PowerShell's -is operator:
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> = <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Item</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$env</span>:SystemRoot
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeOfType System<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>IO<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>DirectoryInfo <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass; object is a DirectoryInfo</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeOfType System<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>IO<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>FileSystemInfo <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass; DirectoryInfo base class is FileSystemInfo</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeOfType System<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>IO<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>FileInfo <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail; FileInfo is not a base class of DirectoryInfo</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)BeTrue[#](https://pester.dev/docs/usage/assertions#betrue)
#
# Asserts that the value is true, or truthy.
#
# <span class="token boolean" style="box-sizing: border-box; color: rgb(54, 172, 170);">$true</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeTrue
#
# 1 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeTrue
#
# 1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>2<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>3 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeTrue
#
# Copy
#
# ### [](..\..\..\..\..\..)BeFalse[#](https://pester.dev/docs/usage/assertions#befalse)
#
# Asserts that the value is false, or falsy.
#
# <span class="token boolean" style="box-sizing: border-box; color: rgb(54, 172, 170);">$false</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeFalse
#
# 0 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeFalse
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$null</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeFalse
#
# Copy
#
# ### [](..\..\..\..\..\..)HaveCount[#](https://pester.dev/docs/usage/assertions#havecount)
#
# Asserts that a collection has the expected amount of items.
#
# 1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>2<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span>3 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>HaveCount 3
#
# Copy
#
# ### [](..\..\..\..\..\..)Contain[#](https://pester.dev/docs/usage/assertions#contain)
#
# Asserts that the collection contains value specified using PowerShell's -contains operator.
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'a'</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span><span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'b'</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span><span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'c'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Contain b
#
# 1<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>100 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Contain 42
#
# Copy
#
# ### [](..\..\..\..\..\..)Exist[#](https://pester.dev/docs/usage/assertions#exist)
#
# Does not perform any comparison but checks if the object calling Exist is present in a PS Provider. The object must have valid path syntax. It essentially must pass a Test-Path call.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span>\=<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Dir</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">[</span>0<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">]</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>FullName
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Remove-Item</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Exist <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# To test path containing `[ ]` wildcards, escape each bracket with two back-ticks as such `"TestDrive:\``[test``].txt"` or use `Test-Path -LiteralPath $something | Should -Be $true`.
#
# ### [](..\..\..\..\..\..)FileContentMatch[#](https://pester.dev/docs/usage/assertions#filecontentmatch)
#
# Checks to see if a file contains the specified text. This search is not case sensitive and uses regular expressions.
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Set-Content</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Path TestDrive:\\file<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>txt <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Value <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I am a file'</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatch <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I Am'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatch <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'^I.*file$'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatch <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I Am Not'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# **Tip:** Use `[regex]::Escape("pattern")` to match the exact text.
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Set-Content</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Path TestDrive:\\file<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>txt <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Value <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I am a file.'</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatch <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I.am.a.file'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatch <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>\[regex\]::Escape<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I.am.a.file'</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# **Warning:** Make sure the input is either a quoted string or an Item object. Otherwise PowerShell will try to invoke the path, likely throwing an error `Cannot run a document in the middle of a pipeline`.
#
# c:\\file<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>txt <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatch something <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Will throw an error</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'c:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatch something <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Will evaluate correctly</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)FileContentMatchExactly[#](https://pester.dev/docs/usage/assertions#filecontentmatchexactly)
#
# Checks to see if a file contains the specified text. This search is case sensitive and uses regular expressions to match the text.
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Set-Content</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Path TestDrive:\\file<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>txt <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Value <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I am a file.'</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatchExactly <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I am'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatchExactly <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'I Am'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)FileContentMatchMultiline[#](https://pester.dev/docs/usage/assertions#filecontentmatchmultiline)
#
# As opposed to FileContentMatch and FileContentMatchExactly operators, FileContentMatchMultiline presents content of the file being tested as one string object, so that the expression you are comparing it to can consist of several lines.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$Content</span> = <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I am the first line.`nI am the second line."</span>
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Set-Content</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Path TestDrive:\\file<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>txt <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Value <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$Content</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>NoNewline
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatchMultiline <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'first line\.\r?\nI am'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatchMultiline <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'^I am the first.*\n.*second line\.$'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass.</span>
#
# Copy
#
# When using FileContentMatchMultiline operator, `^` and `$` represent the beginning and end of the whole file, instead of the beginning and end of a line.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$Content</span> = <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I am the first line.`nI am the second line."</span>
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Set-Content</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Path TestDrive:\\file<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">.</span>txt <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Value <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$Content</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>NoNewline
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'TestDrive:\file.txt'</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>FileContentMatchMultiline <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'^I am the first line\.$'</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail.</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)Match[#](https://pester.dev/docs/usage/assertions#match)
#
# Uses a regular expression to compare two objects. This comparison is not case sensitive.
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I am a value"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Match</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I Am"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I am a value"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Match</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I am a bad person"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# **Tip:** Use `[regex]::Escape("pattern")` to match the exact text.
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Greg"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Match</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">".reg"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Greg"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Match</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>\[regex\]::Escape<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">".reg"</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)MatchExactly[#](https://pester.dev/docs/usage/assertions#matchexactly)
#
# Uses a regular expression to compare two objects. This comparison is case sensitive.
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I am a value"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>MatchExactly <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I am"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I am a value"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>MatchExactly <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"I Am"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)Throw[#](https://pester.dev/docs/usage/assertions#throw)
#
# Checks if an exception was thrown in the input ScriptBlock. Takes an optional argument to indicate the expected exception message.
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span> foo <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">Throw</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$foo</span> = 1 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">Throw</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span> foo <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Not</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">Throw</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$foo</span> = 1 <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Not</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">Throw</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span> <span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">throw</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"This is a test"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">Throw</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"This is a test"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span> <span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">throw</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"bar"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">Throw</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"This is a test"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# Copy
#
# Note: The exception message match is a `-like` [wildcard match](https://docs.microsoft.com/en-us/powershell/module/microsoft.powershell.core/about/about_comparison_operators?view=powershell-7#matching-operators), so the following assertion will pass:
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">throw</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"foo bar baz"</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">Throw</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"*bar*"</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# Copy
#
# **Warning:** The input object must be a ScriptBlock, otherwise it is processed outside of the assertion.
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Process</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Name <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"process"</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>ErrorAction Stop <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">Throw</span> <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Should pass but fails the test</span>
#
# Copy
#
# **NOTE:** `Throw` is used to validate terminating errors (i.e. exceptions that were thrown). If you want to perform validation against non-terminating errors (i.e. `Write-Error` messages), you can [use the technique described here](https://github.com/pester/Pester/issues/366#issuecomment-489377880).
#
# **NOTE:** If you are calling a cmdlet and want to force all errors to be terminating errors so that they can be caught by `| -Should -Throw`, then append `-ErrorAction Stop` to the cmdlet parameters as shown in the example above.
#
# ### [](..\..\..\..\..\..)BeNullOrEmpty[#](https://pester.dev/docs/usage/assertions#benullorempty)
#
# Checks values for null or empty (strings). The static \[String\]::IsNullOrEmpty() method is used to do the comparison.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$null</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeNullOrEmpty <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$null</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Not</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeNullOrEmpty <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will fail</span>
#
# @<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeNullOrEmpty <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">""</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>BeNullOrEmpty <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Test will pass</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)Because[#](https://pester.dev/docs/usage/assertions#because)
#
# Adds message to test failure message.
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> = <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Actual value"</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"actual value"</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Because <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'Test must pass'</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$actual</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"not actual value"</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Because <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">'Test must fail'</span>
#
# <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># OUTPUT</span>
#
# <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Expected strings to be the same, because Test must fail, but they were different.</span>
#
# <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Expected length: 16</span>
#
# <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Actual length: 12</span>
#
# <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Strings differ at index 0.</span>
#
# <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># Expected: 'not actual value'</span>
#
# <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># But was: 'Actual value'</span>
#
# <span class="token comment" style="box-sizing: border-box; color: rgb(153, 153, 136); font-style: italic;"># -----------^</span>
#
# Copy
#
# ### [](..\..\..\..\..\..)HaveParameter[#](https://pester.dev/docs/usage/assertions#haveparameter)
#
# An assertion operator `-HaveParameter` allows you to check function parameters, and their properties like this:
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Command</span> <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Invoke-WebRequest"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>HaveParameter Uri <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Mandatory
#
# <span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">function</span> f <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span>\[String\] <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$Value</span> = 8<span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span>
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Command</span> f <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>HaveParameter Value <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span><span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Type</span> String
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Command</span> f <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Not</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>HaveParameter Name
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Command</span> f <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>HaveParameter Value <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>DefaultValue 8
#
# <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Get-Command</span> f <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>HaveParameter Value <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Not</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Mandatory
#
# Copy
#
# ## [](..\..\..\..\..\..)Using `Should` in a Test[#](https://pester.dev/docs/usage/assertions#using-should-in-a-test)
#
# <span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">function</span> <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Add-Numbers</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">(</span><span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$a</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">,</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$b</span><span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">)</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span>
#
# <span class="token keyword" style="box-sizing: border-box; color: rgb(0, 0, 159);">return</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$a</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">+</span> <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$b</span>
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span>
#
# Describe <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"Add-Numbers"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span>
#
# It <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"adds positive numbers"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$sum</span> = <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Add-Numbers</span> 2 3
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$sum</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be 5
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span>
#
# It <span class="token string" style="box-sizing: border-box; color: rgb(227, 17, 108);">"ensures that 2 + 2 does not equal 5"</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">{</span>
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$sum</span> = <span class="token function" style="box-sizing: border-box; color: rgb(215, 58, 73);">Add-Numbers</span> 2 2
#
# <span class="token variable" style="box-sizing: border-box; color: rgb(54, 172, 170);">$sum</span> <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">|</span> Should <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-Not</span> <span class="token operator" style="box-sizing: border-box; color: rgb(57, 58, 52);">-</span>Be 5
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span>
#
# <span class="token punctuation" style="box-sizing: border-box; color: rgb(57, 58, 52);">}</span>
#
# Copy
#
#
#
# [Performing Assertions with Should | Pester](https://pester.dev/docs/usage/assertions)
